# %%
# !pip install google-generativeai

# %%
import google.generativeai as genai

# %%
from google.colab import userdata
google_api_key=userdata.get('GOOGLE_API_KEY')

# %%
genai.configure(api_key=google_api_key)

# %%
for model in genai.list_models():
  print(model.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# ...

# %%
model=genai.GenerativeModel('gemini-pro')

# %%
response=model.generate_content("what is Machine Learning")
response.text
# Out:
# '**Definition:**\n\nMachine learning (ML) is a subfield of artificial intelligence (AI) that enables computers to learn from data without explicit programming. ML algorithms can identify patterns, make predictions, and improve their performance over time.\n\n**Key Features:**\n\n* **Learning from Data:** ML algorithms learn by analyzing data, such as labeled data (e.g., images with object labels) or unlabeled data (e.g., raw sensor data).\n* **Pattern Recognition:** ML models can extract patterns from data, allowing them to make predictions or classify objects.\n* **Adaptive Behavior:** ML algorithms can adapt their models based on new data and feedback, improving their performance over time.\n* **No Explicit Programming:** ML algorithms learn autonomously from data rather than being explicitly programmed with rules.\n\n**Types of Machine Learning:**\n\n* **Supervised Learning:** Algorithms learn to predict outputs based on labeled data (e.g., training models to identify cats in imag
# ...

# %%
from IPython.display import Markdown
def to_markdown(text):
  display(Markdown(text))
to_markdown(response.text)
# Out:
# **Definition:**
#
# Machine learning (ML) is a subfield of artificial intelligence (AI) that enables computers to learn from data without explicit programming. ML algorithms can identify patterns, make predictions, and improve their performance over time.
#
# **Key Features:**
#
# * **Learning from Data:** ML algorithms learn by analyzing data, such as labeled data (e.g., images with object labels) or unlabeled data (e.g., raw sensor data).
# * **Pattern Recognition:** ML models can extract patterns from data, allowing them to make predictions or classify objects.
# * **Adaptive Behavior:** ML algorithms can adapt their models based on new data and feedback, improving their performance over time.
# * **No Explicit Programming:** ML algorithms learn autonomously from data rather than being explicitly programmed with rules.
#
# **Types of Machine Learning:**
#
# ...

# %%
from IPython.display import Markdown
import textwrap
def to_markdown(text):
  return Markdown(textwrap.indent(text,'>'))
to_markdown(response.text)
# Out:
# >**Definition:**
#
# >Machine learning (ML) is a subfield of artificial intelligence (AI) that enables computers to learn from data without explicit programming. ML algorithms can identify patterns, make predictions, and improve their performance over time.
#
# >**Key Features:**
#
# >* **Learning from Data:** ML algorithms learn by analyzing data, such as labeled data (e.g., images with object labels) or unlabeled data (e.g., raw sensor data).
# >* **Pattern Recognition:** ML models can extract patterns from data, allowing them to make predictions or classify objects.
# >* **Adaptive Behavior:** ML algorithms can adapt their models based on new data and feedback, improving their performance over time.
# >* **No Explicit Programming:** ML algorithms learn autonomously from data rather than being explicitly programmed with rules.
#
# >**Types of Machine Learning:**
#
# ...

# %%
import PIL.Image
img=PIL.Image.open('/content/Untitled.jpeg')
img
# PIL stands for Pillow, which is a Python Imaging Library. It's a powerful tool for opening, manipulating, and saving image files. You probably meant to write PIL instead of pil.
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
model=genai.GenerativeModel('gemini-1.5-flash')

# %%
content="Generate Description"
response=model.generate_content([content,img])
response.text
# Out:
# "That's a stunning photograph of a Bengal tiger! Here are a few description options, depending on the desired tone and context:\n\n**Option 1 (Short & Sweet):**\n\n> A majestic Bengal tiger strides confidently through a sun-drenched forest, its orange and black stripes glowing in the golden light.\n\n\n**Option 2 (More Descriptive):**\n\n> Bathed in the warm hues of the setting sun, a Bengal tiger walks purposefully along a forest path.  Its powerful muscles are subtly visible beneath its striped coat, and its gaze is intense and captivating. The golden light illuminates the details of its fur, highlighting the intricate pattern of its stripes.\n\n\n**Option 3 (Evocative & Poetic):**\n\n> An amber sun paints the forest floor in shades of gold as a Bengal tiger, a creature of myth and majesty, emerges from the shadows.  Its striped form, a masterpiece of nature's artistry, moves with quiet grace, a silent king surveying its domain.\n\n\n**Option 4 (Focus on the Photography):**\n\n> Br
# ...

# %%
content1="which type of tiger it is and what is its color"

# %%
# content="Generate Description"
response=model.generate_content([content1,img])
response.text
# Out:
# "That's a **Bengal tiger**.  Its color is primarily **orange** with **black stripes**.\n"

# %%
from IPython.display import Markdown
def to_markdown(text):
  display(Markdown(text))
to_markdown(response.text)
# Out:
# That's a **Bengal tiger**.  Its color is primarily **orange** with **black stripes**.
